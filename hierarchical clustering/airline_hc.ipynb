# %% [markdown]
# # Assignment no: 7 - Hierarchical Clustering
# # Data set: Airline_data

# %%
# import hierarchical clustering libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
# import dataset in python
df=pd.read_csv('C:/Users/hp/Desktop/DATA SCIENCE COURSE/ASSIGNMENT/ASSIGNMENT 7/EastWestAirlines.csv')
df
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
df1=df.drop(['ID'],axis=1)
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# normalization function
def norm_function(i):
    x=(i-i.min())/(i.max()-i.min())
    return(x)

# %%
df1_norm=norm_function(df1)
df1_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# create dendrogram
plt.figure(figsize=(10, 7))  
dendrogram=sch.dendrogram(sch.linkage(df1_norm,method='complete'))

# %%
#create cluster
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'ward')

# %%
y_hc = hc.fit_predict(df1_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            3
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         4
# 3998         4
#
# [3999 rows x 1 columns]

# %%
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            3
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         4
# 3998         4
#
# [3999 rows x 1 columns]

# %%
df1_norm['h_clusterid'] = Clusters
df1_norm.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# 1     0.023256           0.000000         0.000000           0.839884     0.0
# 2     0.046512           0.000000         0.000000           0.847842     0.0
# 3     0.011628           0.000000         0.000000           0.837955     0.0
# 4     0.302326           0.067398         0.075472           0.835905     1.0
#
#    h_clusterid
# 0            1
# 1            1
# 2            1
# ...

# %%
df1_norm['h_clusterid'].value_counts()
# Out:
# 1    1011
# 0     946
# 2     808
# 4     699
# 3     535
# Name: h_clusterid, dtype: int64

# %%
df1_norm.sort_values('h_clusterid').tail()
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3380  0.007372    0.000000        0.0        0.0        0.0     0.001327
# 3381  0.007736    0.000000        0.0        0.0        0.0     0.005689
# 1014  0.056795    0.098134        0.0        0.0        0.0     0.045888
# 3368  0.015291    0.000000        0.0        0.0        0.0     0.000000
# 3998  0.001769    0.000000        0.0        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3380     0.034884           0.000000         0.000000           0.200386
# 3381     0.034884           0.048674         0.056604           0.235471
# 1014     0.220930           0.262842         0.320755           0.699180
# 3368     0.000000           0.000000         0.000000           0.153846
# 3998     0.000000           0.000000         0.000000           0.168314
#
#       Award?  h_clusterid
# 3380     0.0            4
# 3381     0.0            4
# ...

# %%
plt.figure(figsize=(15,5))
plt.scatter(df1_norm['h_clusterid'],df1_norm['Balance'],c=y_hc,)
